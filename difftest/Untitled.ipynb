# %%
from greenlamp.differential.discrete import diff

import matplotlib.pyplot as plot


t = [0, 0.1, 0.3, 0.4, 0.55, 0.67, 0.71]
x = [23.1, 22.5, 23.5, 21.88, 22.5, 23.5, 24.88]

v = diff(t,x)

plot.plot(t,v)
plot.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from greenlamp.differential.discrete import diff
#       3 import matplotlib.pyplot as plot
#       6 t = [0, 0.1, 0.3, 0.4, 0.55, 0.67, 0.71]
#
# ModuleNotFoundError: No module named 'greenlamp.differential'
